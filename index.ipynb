# %% [markdown]
# # Citizen Science Data Hub — start here
#
# Welcome. Each dataset has its own example notebook; open it and run it cell by cell. The data lives in `/srv/data` (read-only) and your work is saved in your personal folder.
#
# The full gallery, with data sheets and challenges: [https://data.ibercivis.es](https://data.ibercivis.es)
#
#
# ## Astronomy
#
# - [Galaxy Zoo DESI: Detailed Morphology Classifications](galaxy-zoo-desi.ipynb)
# - [SuperWASP Variable Star Photometry Archive (VeSPA)](superwasp-vespa.ipynb)
#
# ## Meteorology
#
# - [Leuven.cool Citizen Science Urban Weather Station Network](leuven-urban-weather.ipynb)
#
# ## Entomology
#
# - [Insect Identification in the Wild: The AMI Dataset](ami-insects.ipynb)
# - [Trends in Butterfly Populations in UK Gardens](uk-butterflies.ipynb)
#
# ## Ornithology
#
# - [Pan-European Common Bird Monitoring Scheme (PECBMS)](pecbms-birds.ipynb)
# - [Tropical Rainforest Birds: Acoustic + eBird Distribution Models](tropical-rainforest-birds.ipynb)
# - [Migratory Connectivity in Wetland Birds (Citizen Science + Isotopes)](wetland-birds-migration.ipynb)
# - [Bird Identification Accuracy in eBird Citizen Science Data (Argentina)](ebird-id-accuracy.ipynb)
#
# ## Phenology
#
# - [MeadoWatch: Wildflower Phenology in Mount Rainier National Park](meadowatch-phenology.ipynb)
# - [PhenoVision: Machine Annotations of Phenology for iNaturalist Plant Photos](phenovision.ipynb)
#
# ## Botany
#
# - [Crowdsourced Vegetation Monitoring: Global Plant Trait Mapping](global-plant-traits.ipynb)
# - [Urban Plant Phenology and Frost Risk (Digitized Herbarium Images)](urban-plant-phenology.ipynb)
#
# ## Urban Botany
#
# - [Fruit-Bearing Plant Species Observations in Brazilian Cities (iNaturalist)](fruit-plants-brazil.ipynb)
#
# ## Air Quality
#
# - [xAire: High-Resolution NO₂ Citizen Science Dataset (Barcelona)](xaire-no2-barcelona.ipynb)
# - [iSCAPE Citizen Science Workshops Air Quality Data](iscape-air-quality.ipynb)
#
# ## Public Health
#
# - [CitieS-Health Barcelona: Air Pollution & Health Survey Results](cities-health-barcelona.ipynb)
#
# ## Urban Acoustics
#
# - [SONYC Urban Sound Tagging (SONYC-UST)](sonyc-urban-sound.ipynb)
#
# ## Citizen Science Metadata
#
# - [CS Track Database: Citizen Science Projects Catalog](cs-track-database.ipynb)
#
# ## Biodiversity
#
# - [Non-random Temporal Patterns of Citizen Science Biodiversity Recording](temporal-patterns-biodiversity.ipynb)
#
# ## Invasive Species
#
# - [GIATAR: Global Invasive and Alien Traits and Records Dataset](giatar-invasive.ipynb)
#
# ## Coasts & Oceanography
#
# - [SCShores: Time-Series of Shorelines from Spanish Sandy Beaches](scshores-shorelines.ipynb)
#
# ## Marine Biodiversity
#
# - [MedSens: Mediterranean Marine Species Abundance (Reef Check Italia)](medsens-mediterranean.ipynb)
# - [MARCSI: Inventory of Marine Citizen Science Initiatives (Global)](marcsi-marine.ipynb)
#
# ## Light Pollution
#
# - [TESS Network Motivation Survey (Light Pollution Citizen Science)](tess-light-pollution.ipynb)
#
# ## Water Quality
#
# - [FLOW: Participant Survey Data from Freshwater Citizen Science Project](flow-freshwater.ipynb)
#
# ## Terrestrial Wildlife
#
# - [Camera Trap Repository: Amsterdamse Waterleidingduinen (Netherlands)](camera-trap-amsterdam.ipynb)
